# %% [markdown]
# # 2022 Store Sales Forecasting Kaggle Competition
#
# ### Merging and Cleaning of the data
#
# Start date: 28/12/2022
# Author: James To

# %%
# import libraries

import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Set data folder path
datafolder = 'C:/Users/James/Documents/Kaggle/Store Sales/data/' #UPDATE

# Read in data
stores_rawdf = pd.read_csv(datafolder + 'stores.csv')
transactions_rawdf = pd.read_csv(datafolder + 'transactions.csv')
train_rawdf = pd.read_csv(datafolder + 'train.csv')
test_rawdf = pd.read_csv(datafolder + 'test.csv')
oil_rawdf = pd.read_csv(datafolder + 'oil.csv')
holidays_events_rawdf = pd.read_csv(datafolder + 'holidays_events.csv')

# %%
# Manipulate train dataset ----

# Split date
train = train_rawdf.copy()
train['year'] = train['date'].str[:4].astype(int)
train['month'] = train['date'].str[5:7].astype(int)
train['day'] = train['date'].str[8:10].astype(int)

# Create a sales to promo ratio
train['sales_to_promo_ratio'] = train['sales'] / train['onpromotion']

# %%
# Make all dates to datetime

# %%
# merged onto training dataset
train_merged = train.merge(stores_rawdf, on = 'store_nbr', how = 'left')
train_merged = train_merged.merge(transactions_rawdf, on = ['date', 'store_nbr'], how = 'left')

# %%
# Check merged dataset
train_merged.tail()
# Out:
#               id        date  store_nbr                      family     sales  \
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio   city  \
# 3000883            0  2017      8   15                   inf  Quito
# 3000884            1  2017      8   15             154.55300  Quito
# 3000885          148  2017      8   15              16.34952  Quito
# 3000886            8  2017      8   15              15.12500  Quito
# 3000887            0  2017      8   15                   inf  Quito
#
#              state type  cluster  transactions
# 3000883  Pichincha    B        6        2155.0
# 3000884  Pichincha    B        6        2155.0
# 3000885  Pichincha    B        6        2155.0
# 3000886  Pichincha    B        6        2155.0
# 3000887  Pichincha    B        6        2155.0

# %%
len(train_merged) == len(train_rawdf)
# Out:
# True

# %% [markdown]
# # Merging Holiday
#
# Merging stores and holiday_events datatsets - rule to get the 'locale name':
# locale = regional -> merged with 'state' column from stores dataset
# local = local -> merged with 'city' column from stores dataset

# %%
# Manipulate holidays events


# Make copy
holidays_events = holidays_events_rawdf.copy()

# Make Navidad one holiday (Christmas)
holidays_events.loc[holidays_events['description'].str.contains('Navidad'), 'description'] = 'Christmas'
navidad_check = holidays_events[holidays_events['description'].str.contains('Navidad')]

# Make Terremoto one holiday
holidays_events.loc[holidays_events['description'].str.contains('Terremoto'), 'description'] = 'Earthquake'
terremoto_check = holidays_events[holidays_events['description'].str.contains('Terremoto')]

# Make futbol one holiday
holidays_events.loc[holidays_events['description'].str.contains('futbol'), 'description'] = '2014 FIFA World Cup'
futbol_check = holidays_events[holidays_events['description'].str.contains('2014 FIFA World Cup')]
print(len(navidad_check), len(terremoto_check), len(futbol_check))
# Out:
# 0 0 14

# %%
# Duplicate dates
date_check = holidays_events.date.value_counts()
date_check
# Out:
# 2014-06-25    4
# 2017-06-25    3
# 2016-06-25    3
# 2015-06-25    3
# 2013-06-25    3
#              ..
# 2014-07-13    1
# 2014-07-12    1
# 2014-07-09    1
# 2014-07-08    1
# 2017-12-26    1
# Name: date, Length: 312, dtype: int64

# %% [markdown]
# ### Split National, Regional, and Local
# For each, remove duplicates and change certain values

# %%
# National
#national = holidays_events[holidays_events.locale == "National"].rename({"description":"holiday_national"}, axis = 1).drop(["locale", "locale_name"], axis = 1).drop_duplicates()

national_subset = holidays_events['locale'] == 'National' #Create subset to only join the regional holidays
holidays_events_national = holidays_events[national_subset]
holidays_events_national = holidays_events_national.rename({"type": "holiday_national_type", "description":"holiday_national", "transferred":"transferred_national"}, axis = 1).drop(["locale", "locale_name"], axis = 1).drop_duplicates('date')
holidays_events_national.tail()
# Out:
#            date holiday_national_type holiday_national  transferred_national
# 345  2017-12-22            Additional        Christmas                 False
# 346  2017-12-23            Additional        Christmas                 False
# 347  2017-12-24            Additional        Christmas                 False
# 348  2017-12-25               Holiday        Christmas                 False
# 349  2017-12-26            Additional        Christmas                 False

# %%
train_national_merged = pd.merge(train_merged, holidays_events_national, on = 'date', how = "left")
check = train_national_merged[~train_national_merged['holiday_national'].isnull()]
check
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 2993755  2993755  2017-08-11          9                     POULTRY   525.224
# 2993756  2993756  2017-08-11          9              PREPARED FOODS   112.100
# 2993757  2993757  2017-08-11          9                     PRODUCE  1453.078
# 2993758  2993758  2017-08-11          9  SCHOOL AND OFFICE SUPPLIES   140.000
# 2993759  2993759  2017-08-11          9                     SEAFOOD    23.831
#
#          onpromotion  year  month  day  sales_to_promo_ratio   city  \
# 0                  0  2013      1    1                   NaN  Quito
# 1                  0  2013      1    1                   NaN  Quito
# 2                  0  2013      1    1                   NaN  Quito
# 3                  0  2013      1    1                   NaN  Quito
# 4                  0  2013      1    1                   NaN  Quito
# ...              ...   ...    ...  ...                   ...    ...
# 2993755           22  2017      8   11             23.873818  Quito
# 2993756            3  2017      8   11             37.366667  Quito
# 2993757            6  2017      8   11            242.179667  Quito
# 2993758            7  2017      8   11             20.000000  Quito
# 2993759            0  2017      8   11                   inf  Quito
#
#              state type  cluster  transactions holiday_national_type  \
# 0        Pichincha    D       13           NaN               Holiday
# 1        Pichincha    D       13           NaN               Holiday
# 2        Pichincha    D       13           NaN               Holiday
# 3        Pichincha    D       13           NaN               Holiday
# 4        Pichincha    D       13           NaN               Holiday
# ...            ...  ...      ...           ...                   ...
# 2993755  Pichincha    B        6        1848.0              Transfer
# 2993756  Pichincha    B        6        1848.0              Transfer
# 2993757  Pichincha    B        6        1848.0              Transfer
# 2993758  Pichincha    B        6        1848.0              Transfer
# 2993759  Pichincha    B        6        1848.0              Transfer
#
#                                holiday_national transferred_national
# 0                            Primer dia del ano                False
# 1                            Primer dia del ano                False
# 2                            Primer dia del ano                False
# 3                            Primer dia del ano                False
# 4                            Primer dia del ano                False
# ...                                         ...                  ...
# 2993755  Traslado Primer Grito de Independencia                False
# 2993756  Traslado Primer Grito de Independencia                False
# 2993757  Traslado Primer Grito de Independencia                False
# 2993758  Traslado Primer Grito de Independencia                False
# 2993759  Traslado Primer Grito de Independencia                False
#
# [254826 rows x 18 columns]

# %%
print(len(train_national_merged))
# Out:
# 3000888

# %%
# Regional
regional_subset = holidays_events['locale'] == 'Regional' #Create subset to only join the regional holidays
holidays_events_regional = holidays_events[regional_subset]
holidays_events_regional = holidays_events_regional.rename({"type": "holiday_regional_type", "locale_name":"state", "description":"holiday_regional", "transferred":"transferred_regional"}, axis = 1).drop("locale", axis = 1).drop_duplicates(subset = ['date', 'state'])

# Decided to scrap the lines below because it may be useful to know if certain regions have more resonance with certain holidays
# Exlcude regional holidays conflicting with national holidays 
#holidays_events_regional = holidays_events_regional[~holidays_events_regional.date.isin(holidays_events_national.date)]

holidays_events_regional.tail()
# Out:
#            date holiday_regional_type                           state  \
# 279  2016-11-07               Holiday                     Santa Elena
# 302  2017-04-01               Holiday                        Cotopaxi
# 315  2017-06-25               Holiday                        Imbabura
# 334  2017-11-06               Holiday  Santo Domingo de los Tsachilas
# 335  2017-11-07               Holiday                     Santa Elena
#
#                        holiday_regional  transferred_regional
# 279       Provincializacion Santa Elena                 False
# 302       Provincializacion de Cotopaxi                 False
# 315       Provincializacion de Imbabura                 False
# 334  Provincializacion de Santo Domingo                 False
# 335       Provincializacion Santa Elena                 False

# %%
train_regional_merged = pd.merge(train_merged, holidays_events_regional, how = 'left', on = ['date', 'state'], validate= 'many_to_one')

# %%
check = train_regional_merged[~train_regional_merged['holiday_regional'].isnull()]
check
# Out:
#               id        date  store_nbr                      family    sales  \
# 160479    160479  2013-04-01         12                  AUTOMOTIVE    3.000
# 160480    160480  2013-04-01         12                   BABY CARE    0.000
# 160481    160481  2013-04-01         12                      BEAUTY    4.000
# 160482    160482  2013-04-01         12                   BEVERAGES  762.000
# 160483    160483  2013-04-01         12                       BOOKS    0.000
# ...          ...         ...        ...                         ...      ...
# 2908450  2908450  2017-06-25         15                     POULTRY   80.431
# 2908451  2908451  2017-06-25         15              PREPARED FOODS   28.000
# 2908452  2908452  2017-06-25         15                     PRODUCE  464.518
# 2908453  2908453  2017-06-25         15  SCHOOL AND OFFICE SUPPLIES    0.000
# 2908454  2908454  2017-06-25         15                     SEAFOOD    3.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio       city  \
# 160479             0  2013      4    1                   inf  Latacunga
# 160480             0  2013      4    1                   NaN  Latacunga
# 160481             0  2013      4    1                   inf  Latacunga
# 160482             0  2013      4    1                   inf  Latacunga
# 160483             0  2013      4    1                   NaN  Latacunga
# ...              ...   ...    ...  ...                   ...        ...
# 2908450            0  2017      6   25                   inf     Ibarra
# 2908451            1  2017      6   25                28.000     Ibarra
# 2908452            1  2017      6   25               464.518     Ibarra
# 2908453            0  2017      6   25                   NaN     Ibarra
# 2908454            0  2017      6   25                   inf     Ibarra
#
#             state type  cluster  transactions holiday_regional_type  \
# 160479   Cotopaxi    C       15        1313.0               Holiday
# 160480   Cotopaxi    C       15        1313.0               Holiday
# 160481   Cotopaxi    C       15        1313.0               Holiday
# 160482   Cotopaxi    C       15        1313.0               Holiday
# 160483   Cotopaxi    C       15        1313.0               Holiday
# ...           ...  ...      ...           ...                   ...
# 2908450  Imbabura    C       15         977.0               Holiday
# 2908451  Imbabura    C       15         977.0               Holiday
# 2908452  Imbabura    C       15         977.0               Holiday
# 2908453  Imbabura    C       15         977.0               Holiday
# 2908454  Imbabura    C       15         977.0               Holiday
#
#                       holiday_regional transferred_regional
# 160479   Provincializacion de Cotopaxi                False
# 160480   Provincializacion de Cotopaxi                False
# 160481   Provincializacion de Cotopaxi                False
# 160482   Provincializacion de Cotopaxi                False
# 160483   Provincializacion de Cotopaxi                False
# ...                                ...                  ...
# 2908450  Provincializacion de Imbabura                False
# 2908451  Provincializacion de Imbabura                False
# 2908452  Provincializacion de Imbabura                False
# 2908453  Provincializacion de Imbabura                False
# 2908454  Provincializacion de Imbabura                False
#
# [1023 rows x 18 columns]

# %%
print(len(train_regional_merged))
# Out:
# 3000888

# %%
# local
local_subset = holidays_events['locale'] == 'Local' #Create subset to only join the local holidays
holidays_events_local = holidays_events[local_subset]
holidays_events_local = holidays_events_local.rename({"type": "holiday_local_type", "locale_name":"city", "description":"holiday_local", "transferred":"transferred_local"}, axis = 1).drop("locale", axis = 1).drop_duplicates(subset = ['date', 'city'])

# Decided to scrap the lines below because it may be useful to know if certain cities have more resonance with certain holidays
# Exlcude local holidays conflicting with national holidays 
#holidays_events_local = holidays_events_local[~holidays_events_local.date.isin(holidays_events_national.date)]

len(holidays_events_local)
# Out:
# 151

# %%
train_local_merged = pd.merge(train_merged, holidays_events_local, how = 'left', on = ['date', 'city'])
check = train_local_merged[~train_local_merged['holiday_local'].isnull()]
check
print(len(train_local_merged))
# Out:
# 3000888

# %%
len(train_rawdf) #== len(train_local_merged)
#len(train_local_merged)
# Out:
# 3000888

# %% [markdown]
# ### Combine all the merges
#
# Combine the national, regional, and local data

# %%
train_national_merged.tail()
# Out:
#               id        date  store_nbr                      family     sales  \
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio   city  \
# 3000883            0  2017      8   15                   inf  Quito
# 3000884            1  2017      8   15             154.55300  Quito
# 3000885          148  2017      8   15              16.34952  Quito
# 3000886            8  2017      8   15              15.12500  Quito
# 3000887            0  2017      8   15                   inf  Quito
#
#              state type  cluster  transactions holiday_national_type  \
# 3000883  Pichincha    B        6        2155.0                   NaN
# 3000884  Pichincha    B        6        2155.0                   NaN
# 3000885  Pichincha    B        6        2155.0                   NaN
# 3000886  Pichincha    B        6        2155.0                   NaN
# 3000887  Pichincha    B        6        2155.0                   NaN
#
#         holiday_national transferred_national
# 3000883              NaN                  NaN
# 3000884              NaN                  NaN
# 3000885              NaN                  NaN
# 3000886              NaN                  NaN
# 3000887              NaN                  NaN

# %%
train_holidays_merged = pd.merge(train_national_merged, train_regional_merged, on = ['id','date','store_nbr','family','sales','onpromotion','year','month','day','sales_to_promo_ratio','type','cluster','transactions', 'city', 'state'], how = 'left')

# %%
check = train_holidays_merged[~train_holidays_merged['holiday_regional'].isnull()]
check
# Out:
#               id        date  store_nbr                      family    sales  \
# 160479    160479  2013-04-01         12                  AUTOMOTIVE    3.000
# 160480    160480  2013-04-01         12                   BABY CARE    0.000
# 160481    160481  2013-04-01         12                      BEAUTY    4.000
# 160482    160482  2013-04-01         12                   BEVERAGES  762.000
# 160483    160483  2013-04-01         12                       BOOKS    0.000
# ...          ...         ...        ...                         ...      ...
# 2908450  2908450  2017-06-25         15                     POULTRY   80.431
# 2908451  2908451  2017-06-25         15              PREPARED FOODS   28.000
# 2908452  2908452  2017-06-25         15                     PRODUCE  464.518
# 2908453  2908453  2017-06-25         15  SCHOOL AND OFFICE SUPPLIES    0.000
# 2908454  2908454  2017-06-25         15                     SEAFOOD    3.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio  ...     state  \
# 160479             0  2013      4    1                   inf  ...  Cotopaxi
# 160480             0  2013      4    1                   NaN  ...  Cotopaxi
# 160481             0  2013      4    1                   inf  ...  Cotopaxi
# 160482             0  2013      4    1                   inf  ...  Cotopaxi
# 160483             0  2013      4    1                   NaN  ...  Cotopaxi
# ...              ...   ...    ...  ...                   ...  ...       ...
# 2908450            0  2017      6   25                   inf  ...  Imbabura
# 2908451            1  2017      6   25                28.000  ...  Imbabura
# 2908452            1  2017      6   25               464.518  ...  Imbabura
# 2908453            0  2017      6   25                   NaN  ...  Imbabura
# 2908454            0  2017      6   25                   inf  ...  Imbabura
#
#         type cluster  transactions  holiday_national_type holiday_national  \
# 160479     C      15        1313.0                    NaN              NaN
# 160480     C      15        1313.0                    NaN              NaN
# 160481     C      15        1313.0                    NaN              NaN
# 160482     C      15        1313.0                    NaN              NaN
# 160483     C      15        1313.0                    NaN              NaN
# ...      ...     ...           ...                    ...              ...
# 2908450    C      15         977.0                    NaN              NaN
# 2908451    C      15         977.0                    NaN              NaN
# 2908452    C      15         977.0                    NaN              NaN
# 2908453    C      15         977.0                    NaN              NaN
# 2908454    C      15         977.0                    NaN              NaN
#
#         transferred_national holiday_regional_type  \
# 160479                   NaN               Holiday
# 160480                   NaN               Holiday
# 160481                   NaN               Holiday
# 160482                   NaN               Holiday
# 160483                   NaN               Holiday
# ...                      ...                   ...
# 2908450                  NaN               Holiday
# 2908451                  NaN               Holiday
# 2908452                  NaN               Holiday
# 2908453                  NaN               Holiday
# 2908454                  NaN               Holiday
#
#                       holiday_regional transferred_regional
# 160479   Provincializacion de Cotopaxi                False
# 160480   Provincializacion de Cotopaxi                False
# 160481   Provincializacion de Cotopaxi                False
# 160482   Provincializacion de Cotopaxi                False
# 160483   Provincializacion de Cotopaxi                False
# ...                                ...                  ...
# 2908450  Provincializacion de Imbabura                False
# 2908451  Provincializacion de Imbabura                False
# 2908452  Provincializacion de Imbabura                False
# 2908453  Provincializacion de Imbabura                False
# 2908454  Provincializacion de Imbabura                False
#
# [1023 rows x 21 columns]

# %%
train_holidays_merged.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion  year  month  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  2013      1
# 1   1  2013-01-01          1   BABY CARE    0.0            0  2013      1
# 2   2  2013-01-01          1      BEAUTY    0.0            0  2013      1
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  2013      1
# 4   4  2013-01-01          1       BOOKS    0.0            0  2013      1
#
#    day  sales_to_promo_ratio  ...      state type cluster  transactions  \
# 0    1                   NaN  ...  Pichincha    D      13           NaN
# 1    1                   NaN  ...  Pichincha    D      13           NaN
# 2    1                   NaN  ...  Pichincha    D      13           NaN
# 3    1                   NaN  ...  Pichincha    D      13           NaN
# 4    1                   NaN  ...  Pichincha    D      13           NaN
#
#    holiday_national_type    holiday_national transferred_national  \
# 0                Holiday  Primer dia del ano                False
# 1                Holiday  Primer dia del ano                False
# 2                Holiday  Primer dia del ano                False
# 3                Holiday  Primer dia del ano                False
# 4                Holiday  Primer dia del ano                False
#
#   holiday_regional_type holiday_regional transferred_regional
# 0                   NaN              NaN                  NaN
# 1                   NaN              NaN                  NaN
# 2                   NaN              NaN                  NaN
# 3                   NaN              NaN                  NaN
# 4                   NaN              NaN                  NaN
#
# [5 rows x 21 columns]

# %%
len(train_holidays_merged)
# Out:
# 3000888

# %%
len(train_holidays_merged) == len(train)
# Out:
# True

# %% [markdown]
# ### Adding local to the holiday merge

# %%
train_holidays_merged = pd.merge(train_holidays_merged, train_local_merged, on = ['id','date','store_nbr','family','sales','onpromotion','year','month','day','sales_to_promo_ratio','type','cluster','transactions', 'city', 'state'], how = 'left')

# %%
train_holidays_merged[~train_holidays_merged['holiday_local'].isnull()]
# Out:
#               id        date  store_nbr                      family    sales  \
# 108471    108471  2013-03-02         52                  AUTOMOTIVE    0.000
# 108472    108472  2013-03-02         52                   BABY CARE    0.000
# 108473    108473  2013-03-02         52                      BEAUTY    0.000
# 108474    108474  2013-03-02         52                   BEVERAGES    0.000
# 108475    108475  2013-03-02         52                       BOOKS    0.000
# ...          ...         ...        ...                         ...      ...
# 2999299  2999299  2017-08-15         14                     POULTRY   50.337
# 2999300  2999300  2017-08-15         14              PREPARED FOODS  107.000
# 2999301  2999301  2017-08-15         14                     PRODUCE  551.648
# 2999302  2999302  2017-08-15         14  SCHOOL AND OFFICE SUPPLIES    4.000
# 2999303  2999303  2017-08-15         14                     SEAFOOD    6.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio  ...  \
# 108471             0  2013      3    2                   NaN  ...
# 108472             0  2013      3    2                   NaN  ...
# 108473             0  2013      3    2                   NaN  ...
# 108474             0  2013      3    2                   NaN  ...
# 108475             0  2013      3    2                   NaN  ...
# ...              ...   ...    ...  ...                   ...  ...
# 2999299            1  2017      8   15             50.337000  ...
# 2999300            0  2017      8   15                   inf  ...
# 2999301           88  2017      8   15              6.268727  ...
# 2999302            3  2017      8   15              1.333333  ...
# 2999303            0  2017      8   15                   inf  ...
#
#         transactions holiday_national_type holiday_national  \
# 108471           NaN                   NaN              NaN
# 108472           NaN                   NaN              NaN
# 108473           NaN                   NaN              NaN
# 108474           NaN                   NaN              NaN
# 108475           NaN                   NaN              NaN
# ...              ...                   ...              ...
# 2999299       1241.0                   NaN              NaN
# 2999300       1241.0                   NaN              NaN
# 2999301       1241.0                   NaN              NaN
# 2999302       1241.0                   NaN              NaN
# 2999303       1241.0                   NaN              NaN
#
#          transferred_national  holiday_regional_type holiday_regional  \
# 108471                    NaN                    NaN              NaN
# 108472                    NaN                    NaN              NaN
# 108473                    NaN                    NaN              NaN
# 108474                    NaN                    NaN              NaN
# 108475                    NaN                    NaN              NaN
# ...                       ...                    ...              ...
# 2999299                   NaN                    NaN              NaN
# 2999300                   NaN                    NaN              NaN
# 2999301                   NaN                    NaN              NaN
# 2999302                   NaN                    NaN              NaN
# 2999303                   NaN                    NaN              NaN
#
#         transferred_regional holiday_local_type          holiday_local  \
# 108471                   NaN            Holiday     Fundacion de Manta
# 108472                   NaN            Holiday     Fundacion de Manta
# 108473                   NaN            Holiday     Fundacion de Manta
# 108474                   NaN            Holiday     Fundacion de Manta
# 108475                   NaN            Holiday     Fundacion de Manta
# ...                      ...                ...                    ...
# 2999299                  NaN            Holiday  Fundacion de Riobamba
# 2999300                  NaN            Holiday  Fundacion de Riobamba
# 2999301                  NaN            Holiday  Fundacion de Riobamba
# 2999302                  NaN            Holiday  Fundacion de Riobamba
# 2999303                  NaN            Holiday  Fundacion de Riobamba
#
#         transferred_local
# 108471              False
# 108472              False
# 108473              False
# 108474              False
# 108475              False
# ...                   ...
# 2999299             False
# 2999300             False
# 2999301             False
# 2999302             False
# 2999303             False
#
# [12243 rows x 24 columns]

# %%
train_holidays_merged[~train_holidays_merged['holiday_national'].isnull()]
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 2993755  2993755  2017-08-11          9                     POULTRY   525.224
# 2993756  2993756  2017-08-11          9              PREPARED FOODS   112.100
# 2993757  2993757  2017-08-11          9                     PRODUCE  1453.078
# 2993758  2993758  2017-08-11          9  SCHOOL AND OFFICE SUPPLIES   140.000
# 2993759  2993759  2017-08-11          9                     SEAFOOD    23.831
#
#          onpromotion  year  month  day  sales_to_promo_ratio  ...  \
# 0                  0  2013      1    1                   NaN  ...
# 1                  0  2013      1    1                   NaN  ...
# 2                  0  2013      1    1                   NaN  ...
# 3                  0  2013      1    1                   NaN  ...
# 4                  0  2013      1    1                   NaN  ...
# ...              ...   ...    ...  ...                   ...  ...
# 2993755           22  2017      8   11             23.873818  ...
# 2993756            3  2017      8   11             37.366667  ...
# 2993757            6  2017      8   11            242.179667  ...
# 2993758            7  2017      8   11             20.000000  ...
# 2993759            0  2017      8   11                   inf  ...
#
#         transactions holiday_national_type  \
# 0                NaN               Holiday
# 1                NaN               Holiday
# 2                NaN               Holiday
# 3                NaN               Holiday
# 4                NaN               Holiday
# ...              ...                   ...
# 2993755       1848.0              Transfer
# 2993756       1848.0              Transfer
# 2993757       1848.0              Transfer
# 2993758       1848.0              Transfer
# 2993759       1848.0              Transfer
#
#                                holiday_national  transferred_national  \
# 0                            Primer dia del ano                 False
# 1                            Primer dia del ano                 False
# 2                            Primer dia del ano                 False
# 3                            Primer dia del ano                 False
# 4                            Primer dia del ano                 False
# ...                                         ...                   ...
# 2993755  Traslado Primer Grito de Independencia                 False
# 2993756  Traslado Primer Grito de Independencia                 False
# 2993757  Traslado Primer Grito de Independencia                 False
# 2993758  Traslado Primer Grito de Independencia                 False
# 2993759  Traslado Primer Grito de Independencia                 False
#
#          holiday_regional_type holiday_regional transferred_regional  \
# 0                          NaN              NaN                  NaN
# 1                          NaN              NaN                  NaN
# 2                          NaN              NaN                  NaN
# 3                          NaN              NaN                  NaN
# 4                          NaN              NaN                  NaN
# ...                        ...              ...                  ...
# 2993755                    NaN              NaN                  NaN
# 2993756                    NaN              NaN                  NaN
# 2993757                    NaN              NaN                  NaN
# 2993758                    NaN              NaN                  NaN
# 2993759                    NaN              NaN                  NaN
#
#         holiday_local_type holiday_local transferred_local
# 0                      NaN           NaN               NaN
# 1                      NaN           NaN               NaN
# 2                      NaN           NaN               NaN
# 3                      NaN           NaN               NaN
# 4                      NaN           NaN               NaN
# ...                    ...           ...               ...
# 2993755                NaN           NaN               NaN
# 2993756                NaN           NaN               NaN
# 2993757                NaN           NaN               NaN
# 2993758                NaN           NaN               NaN
# 2993759                NaN           NaN               NaN
#
# [254826 rows x 24 columns]

# %%
train_holidays_merged[~train_holidays_merged['holiday_regional'].isnull()]
# Out:
#               id        date  store_nbr                      family    sales  \
# 160479    160479  2013-04-01         12                  AUTOMOTIVE    3.000
# 160480    160480  2013-04-01         12                   BABY CARE    0.000
# 160481    160481  2013-04-01         12                      BEAUTY    4.000
# 160482    160482  2013-04-01         12                   BEVERAGES  762.000
# 160483    160483  2013-04-01         12                       BOOKS    0.000
# ...          ...         ...        ...                         ...      ...
# 2908450  2908450  2017-06-25         15                     POULTRY   80.431
# 2908451  2908451  2017-06-25         15              PREPARED FOODS   28.000
# 2908452  2908452  2017-06-25         15                     PRODUCE  464.518
# 2908453  2908453  2017-06-25         15  SCHOOL AND OFFICE SUPPLIES    0.000
# 2908454  2908454  2017-06-25         15                     SEAFOOD    3.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio  ...  \
# 160479             0  2013      4    1                   inf  ...
# 160480             0  2013      4    1                   NaN  ...
# 160481             0  2013      4    1                   inf  ...
# 160482             0  2013      4    1                   inf  ...
# 160483             0  2013      4    1                   NaN  ...
# ...              ...   ...    ...  ...                   ...  ...
# 2908450            0  2017      6   25                   inf  ...
# 2908451            1  2017      6   25                28.000  ...
# 2908452            1  2017      6   25               464.518  ...
# 2908453            0  2017      6   25                   NaN  ...
# 2908454            0  2017      6   25                   inf  ...
#
#         transactions holiday_national_type holiday_national  \
# 160479        1313.0                   NaN              NaN
# 160480        1313.0                   NaN              NaN
# 160481        1313.0                   NaN              NaN
# 160482        1313.0                   NaN              NaN
# 160483        1313.0                   NaN              NaN
# ...              ...                   ...              ...
# 2908450        977.0                   NaN              NaN
# 2908451        977.0                   NaN              NaN
# 2908452        977.0                   NaN              NaN
# 2908453        977.0                   NaN              NaN
# 2908454        977.0                   NaN              NaN
#
#          transferred_national  holiday_regional_type  \
# 160479                    NaN                Holiday
# 160480                    NaN                Holiday
# 160481                    NaN                Holiday
# 160482                    NaN                Holiday
# 160483                    NaN                Holiday
# ...                       ...                    ...
# 2908450                   NaN                Holiday
# 2908451                   NaN                Holiday
# 2908452                   NaN                Holiday
# 2908453                   NaN                Holiday
# 2908454                   NaN                Holiday
#
#                       holiday_regional transferred_regional  \
# 160479   Provincializacion de Cotopaxi                False
# 160480   Provincializacion de Cotopaxi                False
# 160481   Provincializacion de Cotopaxi                False
# 160482   Provincializacion de Cotopaxi                False
# 160483   Provincializacion de Cotopaxi                False
# ...                                ...                  ...
# 2908450  Provincializacion de Imbabura                False
# 2908451  Provincializacion de Imbabura                False
# 2908452  Provincializacion de Imbabura                False
# 2908453  Provincializacion de Imbabura                False
# 2908454  Provincializacion de Imbabura                False
#
#         holiday_local_type holiday_local transferred_local
# 160479                 NaN           NaN               NaN
# 160480                 NaN           NaN               NaN
# 160481                 NaN           NaN               NaN
# 160482                 NaN           NaN               NaN
# 160483                 NaN           NaN               NaN
# ...                    ...           ...               ...
# 2908450                NaN           NaN               NaN
# 2908451                NaN           NaN               NaN
# 2908452                NaN           NaN               NaN
# 2908453                NaN           NaN               NaN
# 2908454                NaN           NaN               NaN
#
# [1023 rows x 24 columns]

# %% [markdown]
# # Merging Oil
#
# This creates the complete dataset after modifying oil data

# %%
# Cleaning oil
oil = oil_rawdf.copy()
oil = oil.rename({'dcoilwtico':'oil_price'}, axis = 1)
oil.tail()
print(oil.isna().sum())
print(oil)
# Out:
# date          0
# oil_price    43
# dtype: int64
#             date  oil_price
# 0     2013-01-01        NaN
# 1     2013-01-02      93.14
# 2     2013-01-03      92.97
# 3     2013-01-04      93.12
# 4     2013-01-07      93.20
# ...          ...        ...
# 1213  2017-08-25      47.65
# 1214  2017-08-28      46.40
# 1215  2017-08-29      46.46
# 1216  2017-08-30      45.96
# 1217  2017-08-31      47.26
#
# [1218 rows x 2 columns]

# %% [markdown]
# ### Impute NAs to be previous oil price

# %%
# NA to previous
oil['oil_price'] = oil['oil_price'].fillna(method='ffill')
print(oil.isna().sum())
print(oil)
# Out:
# date         0
# oil_price    1
# dtype: int64
#             date  oil_price
# 0     2013-01-01        NaN
# 1     2013-01-02      93.14
# 2     2013-01-03      92.97
# 3     2013-01-04      93.12
# 4     2013-01-07      93.20
# ...          ...        ...
# 1213  2017-08-25      47.65
# 1214  2017-08-28      46.40
# 1215  2017-08-29      46.46
# 1216  2017-08-30      45.96
# 1217  2017-08-31      47.26
#
# [1218 rows x 2 columns]

# %%
# remove first row because it is NA
oil = oil.iloc[1:]
print(oil)
# Out:
#             date  oil_price
# 1     2013-01-02      93.14
# 2     2013-01-03      92.97
# 3     2013-01-04      93.12
# 4     2013-01-07      93.20
# 5     2013-01-08      93.21
# ...          ...        ...
# 1213  2017-08-25      47.65
# 1214  2017-08-28      46.40
# 1215  2017-08-29      46.46
# 1216  2017-08-30      45.96
# 1217  2017-08-31      47.26
#
# [1217 rows x 2 columns]

# %% [markdown]
# ### Oil merge

# %%
train_complete_merge = pd.merge(train_holidays_merged, oil, how='left')

# %%
train_complete_merge.tail()
# Out:
#               id        date  store_nbr                      family     sales  \
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio  ...  \
# 3000883            0  2017      8   15                   inf  ...
# 3000884            1  2017      8   15             154.55300  ...
# 3000885          148  2017      8   15              16.34952  ...
# 3000886            8  2017      8   15              15.12500  ...
# 3000887            0  2017      8   15                   inf  ...
#
#         holiday_national_type holiday_national transferred_national  \
# 3000883                   NaN              NaN                  NaN
# 3000884                   NaN              NaN                  NaN
# 3000885                   NaN              NaN                  NaN
# 3000886                   NaN              NaN                  NaN
# 3000887                   NaN              NaN                  NaN
#
#          holiday_regional_type  holiday_regional transferred_regional  \
# 3000883                    NaN               NaN                  NaN
# 3000884                    NaN               NaN                  NaN
# 3000885                    NaN               NaN                  NaN
# 3000886                    NaN               NaN                  NaN
# 3000887                    NaN               NaN                  NaN
#
#         holiday_local_type holiday_local transferred_local oil_price
# 3000883                NaN           NaN               NaN     47.57
# 3000884                NaN           NaN               NaN     47.57
# 3000885                NaN           NaN               NaN     47.57
# 3000886                NaN           NaN               NaN     47.57
# 3000887                NaN           NaN               NaN     47.57
#
# [5 rows x 25 columns]

# %%
len(train_rawdf) == len(train_complete_merge)
# Out:
# True

# %% [markdown]
# # Binarise Holiday Flags
#
# Here we want to binarise the types of holidays/events.

# %%
# Binarise national, regional, local
train_complete_merge["holiday_national_binary"] = np.where(train_complete_merge.holiday_national.notnull(), 1, 0)
train_complete_merge["holiday_regional_binary"] = np.where(train_complete_merge.holiday_regional.notnull(), 1, 0)
train_complete_merge["holiday_local_binary"] = np.where(train_complete_merge.holiday_local.notnull(), 1, 0)

# Binarise earthequake and world cup
train_complete_merge["earthquake_binary"] = np.where(train_complete_merge.holiday_national == "Earthquake", 1, 0)
train_complete_merge["world_cup_binary"] = np.where(train_complete_merge.holiday_national == "2014 FIFA World Cup", 1, 0)

# Christmas flag
train_complete_merge["christmas_binary"] = np.where(train_complete_merge.holiday_national == "Christmas", 1, 0)
train_complete_merge.tail()
# Out:
#               id       date  store_nbr                      family     sales  \
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  year  month  day  sales_to_promo_ratio  ...  \
# 3000883            0  2017      8   15                   inf  ...
# 3000884            1  2017      8   15             154.55300  ...
# 3000885          148  2017      8   15              16.34952  ...
# 3000886            8  2017      8   15              15.12500  ...
# 3000887            0  2017      8   15                   inf  ...
#
#         holiday_national_binary holiday_regional_binary holiday_local_binary  \
# 3000883                       0                       0                    0
# 3000884                       0                       0                    0
# 3000885                       0                       0                    0
# 3000886                       0                       0                    0
# 3000887                       0                       0                    0
#
#          earthquake_binary  world_cup_binary dayofwk flag_1st flag_lastday  \
# 3000883                  0                 0       1        0            0
# 3000884                  0                 0       1        0            0
# 3000885                  0                 0       1        0            0
# 3000886                  0                 0       1        0            0
# 3000887                  0                 0       1        0            0
#
#         flag_15th christmas_binary
# 3000883         1                0
# 3000884         1                0
# 3000885         1                0
# 3000886         1                0
# 3000887         1                0
#
# [5 rows x 35 columns]

# %%
# train_complete_merge.loc[train_complete_merge["holiday_national_binary"] == 1].sum()
print( "National: ", train_complete_merge["holiday_national_binary"].sum(), "Regional: ", train_complete_merge["holiday_regional_binary"].sum(), "Local: ", train_complete_merge["holiday_local_binary"].sum())
print( "Earthquake: ", train_complete_merge["earthquake_binary"].sum(),  "World cup: ", train_complete_merge["earthquake_binary"].sum(), )
print("Christmas: ", train_complete_merge["christmas_binary"].sum())
# Out:
# National:  254826 Regional:  1023 Local:  12243
# Earthquake:  51678 World cup:  51678
# Christmas:  39204

# %% [markdown]
# # Create New Variables

# %%
# Make date to date type
train_complete_merge['date'] = pd.to_datetime(train_complete_merge.date, format='%Y-%m-%d')

# %%
# DAY OF WEEK ----

# Create column for day of week
train_complete_merge['dayofwk'] = train_complete_merge['date'].dt.weekday

# %%
# FLAGS FOR 1ST, 15TH AND LAST DAY OF MONTH ----

# Flag for 1st of month
train_complete_merge['flag_1st'] = train_complete_merge['date'].dt.is_month_start.astype(int)

# Flag for last day of month
train_complete_merge['flag_lastday'] = train_complete_merge['date'].dt.is_month_end.astype(int)

# Flag for 15th of month
train_complete_merge.loc[train_complete_merge['day'] == 15, 'flag_15th'] = 1
train_complete_merge.loc[train_complete_merge['day'] != 15, 'flag_15th'] = 0
train_complete_merge['flag_15th'] = train_complete_merge['flag_15th'].astype(int)

# %%
train_complete_merge.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion  year  month  day  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0  2013      1    1
# 1   1 2013-01-01          1   BABY CARE    0.0            0  2013      1    1
# 2   2 2013-01-01          1      BEAUTY    0.0            0  2013      1    1
# 3   3 2013-01-01          1   BEVERAGES    0.0            0  2013      1    1
# 4   4 2013-01-01          1       BOOKS    0.0            0  2013      1    1
#
#    sales_to_promo_ratio  ... oil_price holiday_national_binary  \
# 0                   NaN  ...       NaN                       1
# 1                   NaN  ...       NaN                       1
# 2                   NaN  ...       NaN                       1
# 3                   NaN  ...       NaN                       1
# 4                   NaN  ...       NaN                       1
#
#   holiday_regional_binary  holiday_local_binary  earthquake_binary  \
# 0                       0                     0                  0
# 1                       0                     0                  0
# 2                       0                     0                  0
# 3                       0                     0                  0
# 4                       0                     0                  0
#
#   world_cup_binary dayofwk flag_1st flag_lastday flag_15th
# 0                0       1        1            0         0
# 1                0       1        1            0         0
# 2                0       1        1            0         0
# 3                0       1        1            0         0
# 4                0       1        1            0         0
#
# [5 rows x 34 columns]
